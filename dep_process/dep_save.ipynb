# %%
import torch
import torchtext

from sklearn.model_selection import train_test_split

import random
import re
# from tqdm import tqdm  # 进度条
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import unicodedata
import datetime
import time
import copy
import math

import sacrebleu
from nltk.translate.bleu_score import sentence_bleu
import pickle
import torch_optimizer as optim
# import adamod
import os
import shutil
import sys

# %%
# 设置超参数
print(' ')
print('dep_save.ipynb')

ngpu = int(sys.argv[1]) #2
print('ngpu：', ngpu)
batch = int(sys.argv[2]) #120
print('batch：', batch)
# MAX_LENGTH = d_model//num_heads
MAX_LENGTH = int(sys.argv[3]) #100
print('MAX_LENGTH：', MAX_LENGTH)
current_datasets_path = sys.argv[4] #'/home/chengkun/jupyter_projects/Magic-NLPer-main/data/en_zh/'
print('current_datasets_path：', current_datasets_path)

train_pairs_path = current_datasets_path + 'train_pairs'
val_pairs_path = current_datasets_path + 'val_pairs'
test_pairs_path = current_datasets_path + 'test_pairs'
# Out:
# ngpu： 2
# batch： 120
# MAX_LENGTH： 100
# EPOCHS： 60
# warm_steps： 3000

# %%
# # 数据读取
# # 当你用read_csv读文件的时候，如果文本里包含英文双引号，直接读取会导致行数变少或是直接如下报错停止
# # 此时应该对read_csv设置参数控制csv中的引号常量，设定quoting=3或是quoting=csv.QUOTE_NONE”（注：用第二种要先导csv库）然后问题就解决了。

# data_dir = '/home/chengkun/jupyter_projects/Magic-NLPer-main/data/' 

# data_df = pd.read_csv(data_dir + 'ch_mn_50_nodict.txt',  # 数据格式：英语\t法语，注意我们的任务源语言是法语，目标语言是英语
#                       encoding='UTF-8', sep='\t', header=None,quoting=3,
#                       names=['src', 'targ'], index_col=False)

# # print(data_df.shape)
# # print(data_df.values.shape)
# # print(data_df.values[0])
# # print(data_df.values[0].shape)
# # data_df.head()

# %%
# # 数据预处理

# # 规范化字符串
# def normalizeString(s):
#     # print(s) # list  ['Go.']
#     # s = s[0]
#     s = s.lower().strip()
#     #s = unicodeToAscii(s)
#     #s = re.sub(r"([.!?])", r" \1", s)  # \1表示group(1)即第一个匹配到的 即匹配到'.'或者'!'或者'?'后，一律替换成'空格.'或者'空格!'或者'空格？'
#     #s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)  # 非字母以及非.!?的其他任何字符 一律被替换成空格
#     s = re.sub(r'[\s]+', " ", s)  # 将出现的多个空格，都使用一个空格代替。例如：w='abc  1   23  1' 处理后：w='abc 1 23 1'
#     return s


# # print(normalizeString('Va !'))
# # print(normalizeString('Go.'))

# %%
# pairs = [[normalizeString(s) for s in line] for line in data_df.values]

# print('pairs num=', len(pairs))
# # print(pairs[0])
# # print(pairs[0])

# %%
# # 文件是英译法，我们实现的是法译英，所以进行了reverse，所以pair[1]是英语
# # 为了快速训练，仅保留“我是”“你是”“他是”等简单句子，并且删除原始文本长度大于10个标记的样本
# def filterPair(p):
#     return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH 

# def filterPairs(pairs):
#     # 过滤，并交换句子顺序，得到法英句子对（之前是英法句子对）
#     return [[pair[1], pair[0]] for pair in pairs if filterPair(pair)]


# pairs = filterPairs(pairs)

# print('经过过滤后平行语料数目为：', len(pairs))
# # print(pairs[0])
# # print(random.choice(pairs))
# # print(np.array(pairs).shape)

# %%
# # 划分数据集：训练集和验证集
# ##0.0338 0.03485
# ##50 0.020 0.020
# train_test, val_pairs = train_test_split(pairs, test_size=0.020, random_state=1234)
# train_pairs, test_pairs = train_test_split(train_test, test_size=0.020, random_state=1234)

# print('训练集句子数目：', len(train_pairs))
# print('验证集句子数目：', len(val_pairs))
# print('测试集句子数目：', len(test_pairs))
# # print(test_pairs[0])

# %%
# with open(r'/home/chengkun/jupyter_projects/Magic-NLPer-main/data/data_sets/train_pairs','wb') as f:
#     pickle.dump(train_pairs, f)
#     f.close()

# with open(r'/home/chengkun/jupyter_projects/Magic-NLPer-main/data/data_sets/val_pairs','wb') as f:
#     pickle.dump(val_pairs, f)
#     f.close()

# with open(r'/home/chengkun/jupyter_projects/Magic-NLPer-main/data/data_sets/test_pairs','wb') as f:
#     pickle.dump(test_pairs, f)
#     f.close()

# %%
with open(train_pairs_path,'rb') as f:
    train_pairs = pickle.load(f)
    f.close()

with open(val_pairs_path,'rb') as f:
    val_pairs = pickle.load(f)
    f.close()

with open(test_pairs_path,'rb') as f:
    test_pairs = pickle.load(f)
    f.close()

print('训练集句子数目：', len(train_pairs))
print('验证集句子数目：', len(val_pairs))
print('测试集句子数目：', len(test_pairs))
# Out:
# 训练集句子数目： 161754
# 验证集句子数目： 5158
# 测试集句子数目： 5003

# %%
tokenizer = lambda x: x.split() # 分词器

SRC_TEXT = torchtext.data.Field(sequential=True,
                                tokenize=tokenizer,
                                # lower=True,
                                fix_length=MAX_LENGTH + 2,
                                preprocessing=lambda x: ['<start>'] + x + ['<end>'],
                                # after tokenizing but before numericalizing
                                # postprocessing # after numericalizing but before the numbers are turned into a Tensor
                                )
TARG_TEXT = torchtext.data.Field(sequential=True,
                                 tokenize=tokenizer,
                                 # lower=True,
                                 fix_length=MAX_LENGTH + 2,
                                 preprocessing=lambda x: ['<start>'] + x + ['<end>'],
                                 )


def get_dataset(pairs, src, targ):
    fields = [('src', src), ('targ', targ)]  # filed信息 fields dict[str, Field])
    examples = []  # list(Example)
    for src, targ in pairs: # 进度条
        # 创建Example时会调用field.preprocess方法
        examples.append(torchtext.data.Example.fromlist([src, targ], fields))
    return examples, fields


# examples, fields = get_dataset(pairs, SRC_TEXT, TARG_TEXT)

ds_train = torchtext.data.Dataset(*get_dataset(train_pairs, SRC_TEXT, TARG_TEXT))
ds_val = torchtext.data.Dataset(*get_dataset(val_pairs, SRC_TEXT, TARG_TEXT))
ds_test = torchtext.data.Dataset(*get_dataset(test_pairs, SRC_TEXT, TARG_TEXT))

# %%
# # 查看1个样本的信息
print('ds_train')
print(len(ds_train[0].src), ds_train[0].src)
print(len(ds_train[0].targ), ds_train[0].targ)
# print('ds_val')
# print(len(ds_val[0].src), ds_val[0].src)
# print(len(ds_val[0].targ), ds_val[0].targ)
# print('ds_test')
# print(len(ds_test[0].src), ds_test[0].src)
# print(len(ds_test[0].targ), ds_test[0].targ)
# Out:
# ds_train
# 29 ['<start>', 'adding', 'these', 'individuals', 'to', 'those', 'officially', 'classified', 'as', 'unemployed', 'implies', 'that', 'about', '1', '5', 'of', 'potential', 'labor', '-', 'force', 'participants', 'are', 'working', 'less', 'than', 'they', 'want', '.', '<end>']
# 39 ['<start>', '将', '这', '些', '个', '人', '加', '到', '被', '官', '方', '失', '业', '统', '计', '口', '径', '中', '，', '则', '有', '1', '5', '的', '潜', '在', '劳', '动', '参', '与', '者', '不', '能', '如', '愿', '工', '作', '。', '<end>']
# ds_val
# 16 ['<start>', 'once', 'again', 'pope', 'john', 'paul', 'ii', 'has', 'returned', 'to', 'hospital', ',', 'gravely', 'ill', '.', '<end>']
# 19 ['<start>', '保', '罗', '教', '皇', '再', '一', '次', '回', '到', '医', '院', '，', '命', '在', '旦', '夕', '。', '<end>']
# ds_test
# 24 ['<start>', 'moreover', ',', 'the', 'most', 'efficient', 'sources', 'of', 'government', 'revenues', 'at', 'the', 'time', 'were', 'tariffs', 'and', 'taxes', 'collected', 'at', 'the', 'external', 'border', '.', '<end>']
# 33 ['<start>', '此', '外', '，', '当', '时', '，', '最', '高', '效', '的', '的', '政', '府', '收', '入', '之', '源', '是', '关', '税', '和', '取', '自', '外', '部', '边', '界', '的', '税', '收', '。', '<end>']

# %%
# 构建词典
print('模型大小与词表大小正相关，控制词表大小')
SRC_TEXT.build_vocab(ds_train,min_freq=1)  # 建立词表 并建立token和ID的映射关系
# print(len(SRC_TEXT.vocab))
# print(SRC_TEXT.vocab.itos[0])
# print(SRC_TEXT.vocab.itos[1])
# print(SRC_TEXT.vocab.itos[2])
# print(SRC_TEXT.vocab.itos[3])
# print(SRC_TEXT.vocab.stoi['<start>'])
# print(SRC_TEXT.vocab.stoi['<end>'])

# 模拟decode
res = []
for id in range(20):
    res.append(SRC_TEXT.vocab.itos[id])
print('0-20：'+' '.join(res)+'\n')

TARG_TEXT.build_vocab(ds_train,min_freq=1)

# print(len(TARG_TEXT.vocab))
# print(TARG_TEXT.vocab.itos[0])
# print(TARG_TEXT.vocab.itos[1])
# print(TARG_TEXT.vocab.itos[2])
# print(TARG_TEXT.vocab.itos[3])
# print(TARG_TEXT.vocab.stoi['<start>'])
# print(TARG_TEXT.vocab.stoi['<end>'])

input_vocab_size = len(SRC_TEXT.vocab)
target_vocab_size = len(TARG_TEXT.vocab)

print('input_vocab_size：', input_vocab_size)
print('target_vocab_size：', target_vocab_size)
# Out:
# 模型大小与词表大小正相关，控制词表大小
# 0-20：<unk> <pad> the , <end> <start> . to of and in a is that ’ - s for 0 it
#
# input_vocab_size： 40949
# target_vocab_size： 4245

# %%
BATCH_SIZE = batch * ngpu

# 构建数据管道迭代器
train_iter, val_iter, test_iter= torchtext.data.Iterator.splits(
    (ds_train, ds_val, ds_test),
    sort_within_batch=True,
    sort_key=lambda x: len(x.src),
    batch_sizes=(BATCH_SIZE, BATCH_SIZE, BATCH_SIZE)
)

# train_iter = torchtext.data.Iterator.splits(
#     (ds_train),
#     sort_within_batch=True,
#     sort_key=lambda x: len(x.src),
#     batch_sizes=(BATCH_SIZE)
# )

# # 查看数据管道信息，此时会触发postprocessing，如果有的话
# for BATCH in train_iter:
#     # 注意，这里text第0维不是batch，而是seq_len
#     print(BATCH.src.shape, BATCH.targ.shape)  # [12,64], [12,64]
#     break

# %%
# 将数据管道组织成与torch.utils.data.DataLoader相似的inputs, targets的输出形式
class DataLoader:
    def __init__(self, data_iter):
        self.data_iter = data_iter
        self.length = len(data_iter)  # 一共有多少个batch？

    def __len__(self):
        return self.length

    def __iter__(self):
        # 注意，在此处调整text的shape为batch first
        for batch in self.data_iter:
            yield (torch.transpose(batch.src, 0, 1), torch.transpose(batch.targ, 0, 1))


train_dataloader = DataLoader(train_iter)
val_dataloader = DataLoader(val_iter)
test_dataloader = DataLoader(test_iter)

# %%
# 查看数据管道
print('len(train_dataloader):', len(train_dataloader))  # 句子总数/batch数
print('len(val_dataloader):', len(val_dataloader))  # 句子总数/batch数
print('len(test_dataloader):', len(test_dataloader))  # 句子总数/batch数

# for batch_src, batch_targ in train_dataloader:
#     print('batch_src.shape:',batch_src.shape,'\n','batch_targ.shape:',batch_targ.shape)  # [256,12], [256,12]
#     print(batch_src, batch_src.dtype)
#     print(batch_targ, batch_targ.dtype)
#     break
# Out:
# len(train_dataloader): 674
# len(val_dataloader): 22
# len(test_dataloader): 21

# %%
def dep_save(dataloader, dep_file_path, dep_batch_file_path):
    
    if os.path.exists(dep_batch_file_path):  # 如果文件存在则删除文件，可使用以下两种方法。
        os.remove(dep_batch_file_path) 
        print('已删除旧文件dep_train_batch_pairs')
        #os.unlink(dep_batch_file)

    dep_batch_file = open(dep_batch_file_path,'wb')
    
    for step, (inp, targ) in enumerate(dataloader, start=1):
        count = 0
        dependency_matrix = torch.zeros(1,inp.shape[1]-1,inp.shape[1]-1)
        while count < inp.shape[0]:
            try:
                dependency_matrix = torch.cat((dependency_matrix,pickle.load(dep_file_path)),0)
                count = count + 1
            except EOFError:
                print('处理完毕')
                break
        
        dependency_matrix = dependency_matrix[1:,:,:]
        pickle.dump(dependency_matrix,dep_batch_file)
        
        if step%1 == 0:
            print(step, dependency_matrix.shape)
            
    dep_batch_file.close()
    dep_file_path.close()
    return True

# %%
# print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()).replace(' ','_'))
# dep_file_path = open(r'/home/chengkun/jupyter_projects/Magic-NLPer-main/data/data_sets/dep_val_pairs','rb')
# dep_batch_file_path = r'/home/chengkun/jupyter_projects/Magic-NLPer-main/data/data_sets/dep_val_batch_pairs'
# dep_save(val_dataloader, dep_file_path, dep_batch_file_path)
# print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()).replace(' ','_'))

# %%
print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()).replace(' ','_'))
dep_file_path = open(current_datasets_path + 'dep_train_pairs','rb')
dep_batch_file_path = current_datasets_path + 'dep_train_batch_pairs'
dep_save(train_dataloader, dep_file_path, dep_batch_file_path)
print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()).replace(' ','_'))
print('运行结束')
# Out:
# 2021-11-25_11:55:06
# 未找到文件
# 1 torch.Size([240, 101, 101])
# 2 torch.Size([240, 101, 101])
# 3 torch.Size([240, 101, 101])
# 4 torch.Size([240, 101, 101])
# 5 torch.Size([240, 101, 101])
# 6 torch.Size([240, 101, 101])
# 7 torch.Size([240, 101, 101])
# 8 torch.Size([240, 101, 101])
# 9 torch.Size([240, 101, 101])
# 10 torch.Size([240, 101, 101])
# 11 torch.Size([240, 101, 101])
# 12 torch.Size([240, 101, 101])
# 13 torch.Size([240, 101, 101])
# 14 torch.Size([240, 101, 101])
# 15 torch.Size([240, 101, 101])
# 16 torch.Size([240, 101, 101])
# 17 torch.Size([240, 101, 101])
# 18 torch.Size([240, 101, 101])
# 19 torch.Size([240, 101, 101])
# 20 torch.Size([240, 101, 101])
# 21 torch.Size([240, 101, 101])
# 处理完毕
# 22 torch.Size([118, 101, 101])
# 处理完毕
# 23 torch.Size([0, 101, 101])
# 处理完毕
# 24 torch.Size([0, 101, 101])
# 处理完毕
# 25 torch.Size([0, 101, 101])
# 处理完毕
# 26 torch.Size([0, 101, 101])
# 处理完毕
# 27 torch.Size([0, 101, 101])
# 处理完毕
# 28 torch.Size([0, 101, 101])
# 处理完毕
# 29 torch.Size([0, 101, 101])
# 处理完毕
# 30 torch.Size([0, 101, 101])
# 处理完毕
# 31 torch.Size([0, 101, 101])
# 处理完毕
# 32 torch.Size([0, 101, 101])
# 处理完毕
# 33 torch.Size([0, 101, 101])
# 处理完毕
# 34 torch.Size([0, 101, 101])
# 处理完毕
# 35 torch.Size([0, 101, 101])
# 处理完毕
# 36 torch.Size([0, 101, 101])
# 处理完毕
# 37 torch.Size([0, 101, 101])
# 处理完毕
# 38 torch.Size([0, 101, 101])
# 处理完毕
# 39 torch.Size([0, 101, 101])
# 处理完毕
# 40 torch.Size([0, 101, 101])
# 处理完毕
# 41 torch.Size([0, 101, 101])
# 处理完毕
# 42 torch.Size([0, 101, 101])
# 处理完毕
# 43 torch.Size([0, 101, 101])
# 处理完毕
# 44 torch.Size([0, 101, 101])
# 处理完毕
# 45 torch.Size([0, 101, 101])
# 处理完毕
# 46 torch.Size([0, 101, 101])
# 处理完毕
# 47 torch.Size([0, 101, 101])
# 处理完毕
# 48 torch.Size([0, 101, 101])
# 处理完毕
# 49 torch.Size([0, 101, 101])
# 处理完毕
# 50 torch.Size([0, 101, 101])
# 处理完毕
# 51 torch.Size([0, 101, 101])
# 处理完毕
# 52 torch.Size([0, 101, 101])
# 处理完毕
# 53 torch.Size([0, 101, 101])
# 处理完毕
# 54 torch.Size([0, 101, 101])
# 处理完毕
# 55 torch.Size([0, 101, 101])
# 处理完毕
# 56 torch.Size([0, 101, 101])
# 处理完毕
# 57 torch.Size([0, 101, 101])
# 处理完毕
# 58 torch.Size([0, 101, 101])
# 处理完毕
# 59 torch.Size([0, 101, 101])
# 处理完毕
# 60 torch.Size([0, 101, 101])
# 处理完毕
# 61 torch.Size([0, 101, 101])
# 处理完毕
# 62 torch.Size([0, 101, 101])
# 处理完毕
# 63 torch.Size([0, 101, 101])
# 处理完毕
# 64 torch.Size([0, 101, 101])
# 处理完毕
# 65 torch.Size([0, 101, 101])
# 处理完毕
# 66 torch.Size([0, 101, 101])
# 处理完毕
# 67 torch.Size([0, 101, 101])
# 处理完毕
# 68 torch.Size([0, 101, 101])
# 处理完毕
# 69 torch.Size([0, 101, 101])
# 处理完毕
# 70 torch.Size([0, 101, 101])
# 处理完毕
# 71 torch.Size([0, 101, 101])
# 处理完毕
# 72 torch.Size([0, 101, 101])
# 处理完毕
# 73 torch.Size([0, 101, 101])
# 处理完毕
# 74 torch.Size([0, 101, 101])
# 处理完毕
# 75 torch.Size([0, 101, 101])
# 处理完毕
# 76 torch.Size([0, 101, 101])
# 处理完毕
# 77 torch.Size([0, 101, 101])
# 处理完毕
# 78 torch.Size([0, 101, 101])
# 处理完毕
# 79 torch.Size([0, 101, 101])
# 处理完毕
# 80 torch.Size([0, 101, 101])
# 处理完毕
# 81 torch.Size([0, 101, 101])
# 处理完毕
# 82 torch.Size([0, 101, 101])
# 处理完毕
# 83 torch.Size([0, 101, 101])
# 处理完毕
# 84 torch.Size([0, 101, 101])
# 处理完毕
# 85 torch.Size([0, 101, 101])
# 处理完毕
# 86 torch.Size([0, 101, 101])
# 处理完毕
# 87 torch.Size([0, 101, 101])
# 处理完毕
# 88 torch.Size([0, 101, 101])
# 处理完毕
# 89 torch.Size([0, 101, 101])
# 处理完毕
# 90 torch.Size([0, 101, 101])
# 处理完毕
# 91 torch.Size([0, 101, 101])
# 处理完毕
# 92 torch.Size([0, 101, 101])
# 处理完毕
# 93 torch.Size([0, 101, 101])
# 处理完毕
# 94 torch.Size([0, 101, 101])
# 处理完毕
# 95 torch.Size([0, 101, 101])
# 处理完毕
# 96 torch.Size([0, 101, 101])
# 处理完毕
# 97 torch.Size([0, 101, 101])
# 处理完毕
# 98 torch.Size([0, 101, 101])
# 处理完毕
# 99 torch.Size([0, 101, 101])
# 处理完毕
# 100 torch.Size([0, 101, 101])
# 处理完毕
# 101 torch.Size([0, 101, 101])
# 处理完毕
# 102 torch.Size([0, 101, 101])
# 处理完毕
# 103 torch.Size([0, 101, 101])
# 处理完毕
# 104 torch.Size([0, 101, 101])
# 处理完毕
# 105 torch.Size([0, 101, 101])
# 处理完毕
# 106 torch.Size([0, 101, 101])
# 处理完毕
# 107 torch.Size([0, 101, 101])
# 处理完毕
# 108 torch.Size([0, 101, 101])
# 处理完毕
# 109 torch.Size([0, 101, 101])
# 处理完毕
# 110 torch.Size([0, 101, 101])
# 处理完毕
# 111 torch.Size([0, 101, 101])
# 处理完毕
# 112 torch.Size([0, 101, 101])
# 处理完毕
# 113 torch.Size([0, 101, 101])
# 处理完毕
# 114 torch.Size([0, 101, 101])
# 处理完毕
# 115 torch.Size([0, 101, 101])
# 处理完毕
# 116 torch.Size([0, 101, 101])
# 处理完毕
# 117 torch.Size([0, 101, 101])
# 处理完毕
# 118 torch.Size([0, 101, 101])
# 处理完毕
# 119 torch.Size([0, 101, 101])
# 处理完毕
# 120 torch.Size([0, 101, 101])
# 处理完毕
# 121 torch.Size([0, 101, 101])
# 处理完毕
# 122 torch.Size([0, 101, 101])
# 处理完毕
# 123 torch.Size([0, 101, 101])
# 处理完毕
# 124 torch.Size([0, 101, 101])
# 处理完毕
# 125 torch.Size([0, 101, 101])
# 处理完毕
# 126 torch.Size([0, 101, 101])
# 处理完毕
# 127 torch.Size([0, 101, 101])
# 处理完毕
# 128 torch.Size([0, 101, 101])
# 处理完毕
# 129 torch.Size([0, 101, 101])
# 处理完毕
# 130 torch.Size([0, 101, 101])
# 处理完毕
# 131 torch.Size([0, 101, 101])
# 处理完毕
# 132 torch.Size([0, 101, 101])
# 处理完毕
# 133 torch.Size([0, 101, 101])
# 处理完毕
# 134 torch.Size([0, 101, 101])
# 处理完毕
# 135 torch.Size([0, 101, 101])
# 处理完毕
# 136 torch.Size([0, 101, 101])
# 处理完毕
# 137 torch.Size([0, 101, 101])
# 处理完毕
# 138 torch.Size([0, 101, 101])
# 处理完毕
# 139 torch.Size([0, 101, 101])
# 处理完毕
# 140 torch.Size([0, 101, 101])
# 处理完毕
# 141 torch.Size([0, 101, 101])
# 处理完毕
# 142 torch.Size([0, 101, 101])
# 处理完毕
# 143 torch.Size([0, 101, 101])
# 处理完毕
# 144 torch.Size([0, 101, 101])
# 处理完毕
# 145 torch.Size([0, 101, 101])
# 处理完毕
# 146 torch.Size([0, 101, 101])
# 处理完毕
# 147 torch.Size([0, 101, 101])
# 处理完毕
# 148 torch.Size([0, 101, 101])
# 处理完毕
# 149 torch.Size([0, 101, 101])
# 处理完毕
# 150 torch.Size([0, 101, 101])
# 处理完毕
# 151 torch.Size([0, 101, 101])
# 处理完毕
# 152 torch.Size([0, 101, 101])
# 处理完毕
# 153 torch.Size([0, 101, 101])
# 处理完毕
# 154 torch.Size([0, 101, 101])
# 处理完毕
# 155 torch.Size([0, 101, 101])
# 处理完毕
# 156 torch.Size([0, 101, 101])
# 处理完毕
# 157 torch.Size([0, 101, 101])
# 处理完毕
# 158 torch.Size([0, 101, 101])
# 处理完毕
# 159 torch.Size([0, 101, 101])
# 处理完毕
# 160 torch.Size([0, 101, 101])
# 处理完毕
# 161 torch.Size([0, 101, 101])
# 处理完毕
# 162 torch.Size([0, 101, 101])
# 处理完毕
# 163 torch.Size([0, 101, 101])
# 处理完毕
# 164 torch.Size([0, 101, 101])
# 处理完毕
# 165 torch.Size([0, 101, 101])
# 处理完毕
# 166 torch.Size([0, 101, 101])
# 处理完毕
# 167 torch.Size([0, 101, 101])
# 处理完毕
# 168 torch.Size([0, 101, 101])
# 处理完毕
# 169 torch.Size([0, 101, 101])
# 处理完毕
# 170 torch.Size([0, 101, 101])
# 处理完毕
# 171 torch.Size([0, 101, 101])
# 处理完毕
# 172 torch.Size([0, 101, 101])
# 处理完毕
# 173 torch.Size([0, 101, 101])
# 处理完毕
# 174 torch.Size([0, 101, 101])
# 处理完毕
# 175 torch.Size([0, 101, 101])
# 处理完毕
# 176 torch.Size([0, 101, 101])
# 处理完毕
# 177 torch.Size([0, 101, 101])
# 处理完毕
# 178 torch.Size([0, 101, 101])
# 处理完毕
# 179 torch.Size([0, 101, 101])
# 处理完毕
# 180 torch.Size([0, 101, 101])
# 处理完毕
# 181 torch.Size([0, 101, 101])
# 处理完毕
# 182 torch.Size([0, 101, 101])
# 处理完毕
# 183 torch.Size([0, 101, 101])
# 处理完毕
# 184 torch.Size([0, 101, 101])
# 处理完毕
# 185 torch.Size([0, 101, 101])
# 处理完毕
# 186 torch.Size([0, 101, 101])
# 处理完毕
# 187 torch.Size([0, 101, 101])
# 处理完毕
# 188 torch.Size([0, 101, 101])
# 处理完毕
# 189 torch.Size([0, 101, 101])
# 处理完毕
# 190 torch.Size([0, 101, 101])
# 处理完毕
# 191 torch.Size([0, 101, 101])
# 处理完毕
# 192 torch.Size([0, 101, 101])
# 处理完毕
# 193 torch.Size([0, 101, 101])
# 处理完毕
# 194 torch.Size([0, 101, 101])
# 处理完毕
# 195 torch.Size([0, 101, 101])
# 处理完毕
# 196 torch.Size([0, 101, 101])
# 处理完毕
# 197 torch.Size([0, 101, 101])
# 处理完毕
# 198 torch.Size([0, 101, 101])
# 处理完毕
# 199 torch.Size([0, 101, 101])
# 处理完毕
# 200 torch.Size([0, 101, 101])
# 处理完毕
# 201 torch.Size([0, 101, 101])
# 处理完毕
# 202 torch.Size([0, 101, 101])
# 处理完毕
# 203 torch.Size([0, 101, 101])
# 处理完毕
# 204 torch.Size([0, 101, 101])
# 处理完毕
# 205 torch.Size([0, 101, 101])
# 处理完毕
# 206 torch.Size([0, 101, 101])
# 处理完毕
# 207 torch.Size([0, 101, 101])
# 处理完毕
# 208 torch.Size([0, 101, 101])
# 处理完毕
# 209 torch.Size([0, 101, 101])
# 处理完毕
# 210 torch.Size([0, 101, 101])
# 处理完毕
# 211 torch.Size([0, 101, 101])
# 处理完毕
# 212 torch.Size([0, 101, 101])
# 处理完毕
# 213 torch.Size([0, 101, 101])
# 处理完毕
# 214 torch.Size([0, 101, 101])
# 处理完毕
# 215 torch.Size([0, 101, 101])
# 处理完毕
# 216 torch.Size([0, 101, 101])
# 处理完毕
# 217 torch.Size([0, 101, 101])
# 处理完毕
# 218 torch.Size([0, 101, 101])
# 处理完毕
# 219 torch.Size([0, 101, 101])
# 处理完毕
# 220 torch.Size([0, 101, 101])
# 处理完毕
# 221 torch.Size([0, 101, 101])
# 处理完毕
# 222 torch.Size([0, 101, 101])
# 处理完毕
# 223 torch.Size([0, 101, 101])
# 处理完毕
# 224 torch.Size([0, 101, 101])
# 处理完毕
# 225 torch.Size([0, 101, 101])
# 处理完毕
# 226 torch.Size([0, 101, 101])
# 处理完毕
# 227 torch.Size([0, 101, 101])
# 处理完毕
# 228 torch.Size([0, 101, 101])
# 处理完毕
# 229 torch.Size([0, 101, 101])
# 处理完毕
# 230 torch.Size([0, 101, 101])
# 处理完毕
# 231 torch.Size([0, 101, 101])
# 处理完毕
# 232 torch.Size([0, 101, 101])
# 处理完毕
# 233 torch.Size([0, 101, 101])
# 处理完毕
# 234 torch.Size([0, 101, 101])
# 处理完毕
# 235 torch.Size([0, 101, 101])
# 处理完毕
# 236 torch.Size([0, 101, 101])
# 处理完毕
# 237 torch.Size([0, 101, 101])
# 处理完毕
# 238 torch.Size([0, 101, 101])
# 处理完毕
# 239 torch.Size([0, 101, 101])
# 处理完毕
# 240 torch.Size([0, 101, 101])
# 处理完毕
# 241 torch.Size([0, 101, 101])
# 处理完毕
# 242 torch.Size([0, 101, 101])
# 处理完毕
# 243 torch.Size([0, 101, 101])
# 处理完毕
# 244 torch.Size([0, 101, 101])
# 处理完毕
# 245 torch.Size([0, 101, 101])
# 处理完毕
# 246 torch.Size([0, 101, 101])
# 处理完毕
# 247 torch.Size([0, 101, 101])
# 处理完毕
# 248 torch.Size([0, 101, 101])
# 处理完毕
# 249 torch.Size([0, 101, 101])
# 处理完毕
# 250 torch.Size([0, 101, 101])
# 处理完毕
# 251 torch.Size([0, 101, 101])
# 处理完毕
# 252 torch.Size([0, 101, 101])
# 处理完毕
# 253 torch.Size([0, 101, 101])
# 处理完毕
# 254 torch.Size([0, 101, 101])
# 处理完毕
# 255 torch.Size([0, 101, 101])
# 处理完毕
# 256 torch.Size([0, 101, 101])
# 处理完毕
# 257 torch.Size([0, 101, 101])
# 处理完毕
# 258 torch.Size([0, 101, 101])
# 处理完毕
# 259 torch.Size([0, 101, 101])
# 处理完毕
# 260 torch.Size([0, 101, 101])
# 处理完毕
# 261 torch.Size([0, 101, 101])
# 处理完毕
# 262 torch.Size([0, 101, 101])
# 处理完毕
# 263 torch.Size([0, 101, 101])
# 处理完毕
# 264 torch.Size([0, 101, 101])
# 处理完毕
# 265 torch.Size([0, 101, 101])
# 处理完毕
# 266 torch.Size([0, 101, 101])
# 处理完毕
# 267 torch.Size([0, 101, 101])
# 处理完毕
# 268 torch.Size([0, 101, 101])
# 处理完毕
# 269 torch.Size([0, 101, 101])
# 处理完毕
# 270 torch.Size([0, 101, 101])
# 处理完毕
# 271 torch.Size([0, 101, 101])
# 处理完毕
# 272 torch.Size([0, 101, 101])
# 处理完毕
# 273 torch.Size([0, 101, 101])
# 处理完毕
# 274 torch.Size([0, 101, 101])
# 处理完毕
# 275 torch.Size([0, 101, 101])
# 处理完毕
# 276 torch.Size([0, 101, 101])
# 处理完毕
# 277 torch.Size([0, 101, 101])
# 处理完毕
# 278 torch.Size([0, 101, 101])
# 处理完毕
# 279 torch.Size([0, 101, 101])
# 处理完毕
# 280 torch.Size([0, 101, 101])
# 处理完毕
# 281 torch.Size([0, 101, 101])
# 处理完毕
# 282 torch.Size([0, 101, 101])
# 处理完毕
# 283 torch.Size([0, 101, 101])
# 处理完毕
# 284 torch.Size([0, 101, 101])
# 处理完毕
# 285 torch.Size([0, 101, 101])
# 处理完毕
# 286 torch.Size([0, 101, 101])
# 处理完毕
# 287 torch.Size([0, 101, 101])
# 处理完毕
# 288 torch.Size([0, 101, 101])
# 处理完毕
# 289 torch.Size([0, 101, 101])
# 处理完毕
# 290 torch.Size([0, 101, 101])
# 处理完毕
# 291 torch.Size([0, 101, 101])
# 处理完毕
# 292 torch.Size([0, 101, 101])
# 处理完毕
# 293 torch.Size([0, 101, 101])
# 处理完毕
# 294 torch.Size([0, 101, 101])
# 处理完毕
# 295 torch.Size([0, 101, 101])
# 处理完毕
# 296 torch.Size([0, 101, 101])
# 处理完毕
# 297 torch.Size([0, 101, 101])
# 处理完毕
# 298 torch.Size([0, 101, 101])
# 处理完毕
# 299 torch.Size([0, 101, 101])
# 处理完毕
# 300 torch.Size([0, 101, 101])
# 处理完毕
# 301 torch.Size([0, 101, 101])
# 处理完毕
# 302 torch.Size([0, 101, 101])
# 处理完毕
# 303 torch.Size([0, 101, 101])
# 处理完毕
# 304 torch.Size([0, 101, 101])
# 处理完毕
# 305 torch.Size([0, 101, 101])
# 处理完毕
# 306 torch.Size([0, 101, 101])
# 处理完毕
# 307 torch.Size([0, 101, 101])
# 处理完毕
# 308 torch.Size([0, 101, 101])
# 处理完毕
# 309 torch.Size([0, 101, 101])
# 处理完毕
# 310 torch.Size([0, 101, 101])
# 处理完毕
# 311 torch.Size([0, 101, 101])
# 处理完毕
# 312 torch.Size([0, 101, 101])
# 处理完毕
# 313 torch.Size([0, 101, 101])
# 处理完毕
# 314 torch.Size([0, 101, 101])
# 处理完毕
# 315 torch.Size([0, 101, 101])
# 处理完毕
# 316 torch.Size([0, 101, 101])
# 处理完毕
# 317 torch.Size([0, 101, 101])
# 处理完毕
# 318 torch.Size([0, 101, 101])
# 处理完毕
# 319 torch.Size([0, 101, 101])
# 处理完毕
# 320 torch.Size([0, 101, 101])
# 处理完毕
# 321 torch.Size([0, 101, 101])
# 处理完毕
# 322 torch.Size([0, 101, 101])
# 处理完毕
# 323 torch.Size([0, 101, 101])
# 处理完毕
# 324 torch.Size([0, 101, 101])
# 处理完毕
# 325 torch.Size([0, 101, 101])
# 处理完毕
# 326 torch.Size([0, 101, 101])
# 处理完毕
# 327 torch.Size([0, 101, 101])
# 处理完毕
# 328 torch.Size([0, 101, 101])
# 处理完毕
# 329 torch.Size([0, 101, 101])
# 处理完毕
# 330 torch.Size([0, 101, 101])
# 处理完毕
# 331 torch.Size([0, 101, 101])
# 处理完毕
# 332 torch.Size([0, 101, 101])
# 处理完毕
# 333 torch.Size([0, 101, 101])
# 处理完毕
# 334 torch.Size([0, 101, 101])
# 处理完毕
# 335 torch.Size([0, 101, 101])
# 处理完毕
# 336 torch.Size([0, 101, 101])
# 处理完毕
# 337 torch.Size([0, 101, 101])
# 处理完毕
# 338 torch.Size([0, 101, 101])
# 处理完毕
# 339 torch.Size([0, 101, 101])
# 处理完毕
# 340 torch.Size([0, 101, 101])
# 处理完毕
# 341 torch.Size([0, 101, 101])
# 处理完毕
# 342 torch.Size([0, 101, 101])
# 处理完毕
# 343 torch.Size([0, 101, 101])
# 处理完毕
# 344 torch.Size([0, 101, 101])
# 处理完毕
# 345 torch.Size([0, 101, 101])
# 处理完毕
# 346 torch.Size([0, 101, 101])
# 处理完毕
# 347 torch.Size([0, 101, 101])
# 处理完毕
# 348 torch.Size([0, 101, 101])
# 处理完毕
# 349 torch.Size([0, 101, 101])
# 处理完毕
# 350 torch.Size([0, 101, 101])
# 处理完毕
# 351 torch.Size([0, 101, 101])
# 处理完毕
# 352 torch.Size([0, 101, 101])
# 处理完毕
# 353 torch.Size([0, 101, 101])
# 处理完毕
# 354 torch.Size([0, 101, 101])
# 处理完毕
# 355 torch.Size([0, 101, 101])
# 处理完毕
# 356 torch.Size([0, 101, 101])
# 处理完毕
# 357 torch.Size([0, 101, 101])
# 处理完毕
# 358 torch.Size([0, 101, 101])
# 处理完毕
# 359 torch.Size([0, 101, 101])
# 处理完毕
# 360 torch.Size([0, 101, 101])
# 处理完毕
# 361 torch.Size([0, 101, 101])
# 处理完毕
# 362 torch.Size([0, 101, 101])
# 处理完毕
# 363 torch.Size([0, 101, 101])
# 处理完毕
# 364 torch.Size([0, 101, 101])
# 处理完毕
# 365 torch.Size([0, 101, 101])
# 处理完毕
# 366 torch.Size([0, 101, 101])
# 处理完毕
# 367 torch.Size([0, 101, 101])
# 处理完毕
# 368 torch.Size([0, 101, 101])
# 处理完毕
# 369 torch.Size([0, 101, 101])
# 处理完毕
# 370 torch.Size([0, 101, 101])
# 处理完毕
# 371 torch.Size([0, 101, 101])
# 处理完毕
# 372 torch.Size([0, 101, 101])
# 处理完毕
# 373 torch.Size([0, 101, 101])
# 处理完毕
# 374 torch.Size([0, 101, 101])
# 处理完毕
# 375 torch.Size([0, 101, 101])
# 处理完毕
# 376 torch.Size([0, 101, 101])
# 处理完毕
# 377 torch.Size([0, 101, 101])
# 处理完毕
# 378 torch.Size([0, 101, 101])
# 处理完毕
# 379 torch.Size([0, 101, 101])
# 处理完毕
# 380 torch.Size([0, 101, 101])
# 处理完毕
# 381 torch.Size([0, 101, 101])
# 处理完毕
# 382 torch.Size([0, 101, 101])
# 处理完毕
# 383 torch.Size([0, 101, 101])
# 处理完毕
# 384 torch.Size([0, 101, 101])
# 处理完毕
# 385 torch.Size([0, 101, 101])
# 处理完毕
# 386 torch.Size([0, 101, 101])
# 处理完毕
# 387 torch.Size([0, 101, 101])
# 处理完毕
# 388 torch.Size([0, 101, 101])
# 处理完毕
# 389 torch.Size([0, 101, 101])
# 处理完毕
# 390 torch.Size([0, 101, 101])
# 处理完毕
# 391 torch.Size([0, 101, 101])
# 处理完毕
# 392 torch.Size([0, 101, 101])
# 处理完毕
# 393 torch.Size([0, 101, 101])
# 处理完毕
# 394 torch.Size([0, 101, 101])
# 处理完毕
# 395 torch.Size([0, 101, 101])
# 处理完毕
# 396 torch.Size([0, 101, 101])
# 处理完毕
# 397 torch.Size([0, 101, 101])
# 处理完毕
# 398 torch.Size([0, 101, 101])
# 处理完毕
# 399 torch.Size([0, 101, 101])
# 处理完毕
# 400 torch.Size([0, 101, 101])
# 处理完毕
# 401 torch.Size([0, 101, 101])
# 处理完毕
# 402 torch.Size([0, 101, 101])
# 处理完毕
# 403 torch.Size([0, 101, 101])
# 处理完毕
# 404 torch.Size([0, 101, 101])
# 处理完毕
# 405 torch.Size([0, 101, 101])
# 处理完毕
# 406 torch.Size([0, 101, 101])
# 处理完毕
# 407 torch.Size([0, 101, 101])
# 处理完毕
# 408 torch.Size([0, 101, 101])
# 处理完毕
# 409 torch.Size([0, 101, 101])
# 处理完毕
# 410 torch.Size([0, 101, 101])
# 处理完毕
# 411 torch.Size([0, 101, 101])
# 处理完毕
# 412 torch.Size([0, 101, 101])
# 处理完毕
# 413 torch.Size([0, 101, 101])
# 处理完毕
# 414 torch.Size([0, 101, 101])
# 处理完毕
# 415 torch.Size([0, 101, 101])
# 处理完毕
# 416 torch.Size([0, 101, 101])
# 处理完毕
# 417 torch.Size([0, 101, 101])
# 处理完毕
# 418 torch.Size([0, 101, 101])
# 处理完毕
# 419 torch.Size([0, 101, 101])
# 处理完毕
# 420 torch.Size([0, 101, 101])
# 处理完毕
# 421 torch.Size([0, 101, 101])
# 处理完毕
# 422 torch.Size([0, 101, 101])
# 处理完毕
# 423 torch.Size([0, 101, 101])
# 处理完毕
# 424 torch.Size([0, 101, 101])
# 处理完毕
# 425 torch.Size([0, 101, 101])
# 处理完毕
# 426 torch.Size([0, 101, 101])
# 处理完毕
# 427 torch.Size([0, 101, 101])
# 处理完毕
# 428 torch.Size([0, 101, 101])
# 处理完毕
# 429 torch.Size([0, 101, 101])
# 处理完毕
# 430 torch.Size([0, 101, 101])
# 处理完毕
# 431 torch.Size([0, 101, 101])
# 处理完毕
# 432 torch.Size([0, 101, 101])
# 处理完毕
# 433 torch.Size([0, 101, 101])
# 处理完毕
# 434 torch.Size([0, 101, 101])
# 处理完毕
# 435 torch.Size([0, 101, 101])
# 处理完毕
# 436 torch.Size([0, 101, 101])
# 处理完毕
# 437 torch.Size([0, 101, 101])
# 处理完毕
# 438 torch.Size([0, 101, 101])
# 处理完毕
# 439 torch.Size([0, 101, 101])
# 处理完毕
# 440 torch.Size([0, 101, 101])
# 处理完毕
# 441 torch.Size([0, 101, 101])
# 处理完毕
# 442 torch.Size([0, 101, 101])
# 处理完毕
# 443 torch.Size([0, 101, 101])
# 处理完毕
# 444 torch.Size([0, 101, 101])
# 处理完毕
# 445 torch.Size([0, 101, 101])
# 处理完毕
# 446 torch.Size([0, 101, 101])
# 处理完毕
# 447 torch.Size([0, 101, 101])
# 处理完毕
# 448 torch.Size([0, 101, 101])
# 处理完毕
# 449 torch.Size([0, 101, 101])
# 处理完毕
# 450 torch.Size([0, 101, 101])
# 处理完毕
# 451 torch.Size([0, 101, 101])
# 处理完毕
# 452 torch.Size([0, 101, 101])
# 处理完毕
# 453 torch.Size([0, 101, 101])
# 处理完毕
# 454 torch.Size([0, 101, 101])
# 处理完毕
# 455 torch.Size([0, 101, 101])
# 处理完毕
# 456 torch.Size([0, 101, 101])
# 处理完毕
# 457 torch.Size([0, 101, 101])
# 处理完毕
# 458 torch.Size([0, 101, 101])
# 处理完毕
# 459 torch.Size([0, 101, 101])
# 处理完毕
# 460 torch.Size([0, 101, 101])
# 处理完毕
# 461 torch.Size([0, 101, 101])
# 处理完毕
# 462 torch.Size([0, 101, 101])
# 处理完毕
# 463 torch.Size([0, 101, 101])
# 处理完毕
# 464 torch.Size([0, 101, 101])
# 处理完毕
# 465 torch.Size([0, 101, 101])
# 处理完毕
# 466 torch.Size([0, 101, 101])
# 处理完毕
# 467 torch.Size([0, 101, 101])
# 处理完毕
# 468 torch.Size([0, 101, 101])
# 处理完毕
# 469 torch.Size([0, 101, 101])
# 处理完毕
# 470 torch.Size([0, 101, 101])
# 处理完毕
# 471 torch.Size([0, 101, 101])
# 处理完毕
# 472 torch.Size([0, 101, 101])
# 处理完毕
# 473 torch.Size([0, 101, 101])
# 处理完毕
# 474 torch.Size([0, 101, 101])
# 处理完毕
# 475 torch.Size([0, 101, 101])
# 处理完毕
# 476 torch.Size([0, 101, 101])
# 处理完毕
# 477 torch.Size([0, 101, 101])
# 处理完毕
# 478 torch.Size([0, 101, 101])
# 处理完毕
# 479 torch.Size([0, 101, 101])
# 处理完毕
# 480 torch.Size([0, 101, 101])
# 处理完毕
# 481 torch.Size([0, 101, 101])
# 处理完毕
# 482 torch.Size([0, 101, 101])
# 处理完毕
# 483 torch.Size([0, 101, 101])
# 处理完毕
# 484 torch.Size([0, 101, 101])
# 处理完毕
# 485 torch.Size([0, 101, 101])
# 处理完毕
# 486 torch.Size([0, 101, 101])
# 处理完毕
# 487 torch.Size([0, 101, 101])
# 处理完毕
# 488 torch.Size([0, 101, 101])
# 处理完毕
# 489 torch.Size([0, 101, 101])
# 处理完毕
# 490 torch.Size([0, 101, 101])
# 处理完毕
# 491 torch.Size([0, 101, 101])
# 处理完毕
# 492 torch.Size([0, 101, 101])
# 处理完毕
# 493 torch.Size([0, 101, 101])
# 处理完毕
# 494 torch.Size([0, 101, 101])
# 处理完毕
# 495 torch.Size([0, 101, 101])
# 处理完毕
# 496 torch.Size([0, 101, 101])
# 处理完毕
# 497 torch.Size([0, 101, 101])
# 处理完毕
# 498 torch.Size([0, 101, 101])
# 处理完毕
# 499 torch.Size([0, 101, 101])
# 处理完毕
# 500 torch.Size([0, 101, 101])
# 处理完毕
# 501 torch.Size([0, 101, 101])
# 处理完毕
# 502 torch.Size([0, 101, 101])
# 处理完毕
# 503 torch.Size([0, 101, 101])
# 处理完毕
# 504 torch.Size([0, 101, 101])
# 处理完毕
# 505 torch.Size([0, 101, 101])
# 处理完毕
# 506 torch.Size([0, 101, 101])
# 处理完毕
# 507 torch.Size([0, 101, 101])
# 处理完毕
# 508 torch.Size([0, 101, 101])
# 处理完毕
# 509 torch.Size([0, 101, 101])
# 处理完毕
# 510 torch.Size([0, 101, 101])
# 处理完毕
# 511 torch.Size([0, 101, 101])
# 处理完毕
# 512 torch.Size([0, 101, 101])
# 处理完毕
# 513 torch.Size([0, 101, 101])
# 处理完毕
# 514 torch.Size([0, 101, 101])
# 处理完毕
# 515 torch.Size([0, 101, 101])
# 处理完毕
# 516 torch.Size([0, 101, 101])
# 处理完毕
# 517 torch.Size([0, 101, 101])
# 处理完毕
# 518 torch.Size([0, 101, 101])
# 处理完毕
# 519 torch.Size([0, 101, 101])
# 处理完毕
# 520 torch.Size([0, 101, 101])
# 处理完毕
# 521 torch.Size([0, 101, 101])
# 处理完毕
# 522 torch.Size([0, 101, 101])
# 处理完毕
# 523 torch.Size([0, 101, 101])
# 处理完毕
# 524 torch.Size([0, 101, 101])
# 处理完毕
# 525 torch.Size([0, 101, 101])
# 处理完毕
# 526 torch.Size([0, 101, 101])
# 处理完毕
# 527 torch.Size([0, 101, 101])
# 处理完毕
# 528 torch.Size([0, 101, 101])
# 处理完毕
# 529 torch.Size([0, 101, 101])
# 处理完毕
# 530 torch.Size([0, 101, 101])
# 处理完毕
# 531 torch.Size([0, 101, 101])
# 处理完毕
# 532 torch.Size([0, 101, 101])
# 处理完毕
# 533 torch.Size([0, 101, 101])
# 处理完毕
# 534 torch.Size([0, 101, 101])
# 处理完毕
# 535 torch.Size([0, 101, 101])
# 处理完毕
# 536 torch.Size([0, 101, 101])
# 处理完毕
# 537 torch.Size([0, 101, 101])
# 处理完毕
# 538 torch.Size([0, 101, 101])
# 处理完毕
# 539 torch.Size([0, 101, 101])
# 处理完毕
# 540 torch.Size([0, 101, 101])
# 处理完毕
# 541 torch.Size([0, 101, 101])
# 处理完毕
# 542 torch.Size([0, 101, 101])
# 处理完毕
# 543 torch.Size([0, 101, 101])
# 处理完毕
# 544 torch.Size([0, 101, 101])
# 处理完毕
# 545 torch.Size([0, 101, 101])
# 处理完毕
# 546 torch.Size([0, 101, 101])
# 处理完毕
# 547 torch.Size([0, 101, 101])
# 处理完毕
# 548 torch.Size([0, 101, 101])
# 处理完毕
# 549 torch.Size([0, 101, 101])
# 处理完毕
# 550 torch.Size([0, 101, 101])
# 处理完毕
# 551 torch.Size([0, 101, 101])
# 处理完毕
# 552 torch.Size([0, 101, 101])
# 处理完毕
# 553 torch.Size([0, 101, 101])
# 处理完毕
# 554 torch.Size([0, 101, 101])
# 处理完毕
# 555 torch.Size([0, 101, 101])
# 处理完毕
# 556 torch.Size([0, 101, 101])
# 处理完毕
# 557 torch.Size([0, 101, 101])
# 处理完毕
# 558 torch.Size([0, 101, 101])
# 处理完毕
# 559 torch.Size([0, 101, 101])
# 处理完毕
# 560 torch.Size([0, 101, 101])
# 处理完毕
# 561 torch.Size([0, 101, 101])
# 处理完毕
# 562 torch.Size([0, 101, 101])
# 处理完毕
# 563 torch.Size([0, 101, 101])
# 处理完毕
# 564 torch.Size([0, 101, 101])
# 处理完毕
# 565 torch.Size([0, 101, 101])
# 处理完毕
# 566 torch.Size([0, 101, 101])
# 处理完毕
# 567 torch.Size([0, 101, 101])
# 处理完毕
# 568 torch.Size([0, 101, 101])
# 处理完毕
# 569 torch.Size([0, 101, 101])
# 处理完毕
# 570 torch.Size([0, 101, 101])
# 处理完毕
# 571 torch.Size([0, 101, 101])
# 处理完毕
# 572 torch.Size([0, 101, 101])
# 处理完毕
# 573 torch.Size([0, 101, 101])
# 处理完毕
# 574 torch.Size([0, 101, 101])
# 处理完毕
# 575 torch.Size([0, 101, 101])
# 处理完毕
# 576 torch.Size([0, 101, 101])
# 处理完毕
# 577 torch.Size([0, 101, 101])
# 处理完毕
# 578 torch.Size([0, 101, 101])
# 处理完毕
# 579 torch.Size([0, 101, 101])
# 处理完毕
# 580 torch.Size([0, 101, 101])
# 处理完毕
# 581 torch.Size([0, 101, 101])
# 处理完毕
# 582 torch.Size([0, 101, 101])
# 处理完毕
# 583 torch.Size([0, 101, 101])
# 处理完毕
# 584 torch.Size([0, 101, 101])
# 处理完毕
# 585 torch.Size([0, 101, 101])
# 处理完毕
# 586 torch.Size([0, 101, 101])
# 处理完毕
# 587 torch.Size([0, 101, 101])
# 处理完毕
# 588 torch.Size([0, 101, 101])
# 处理完毕
# 589 torch.Size([0, 101, 101])
# 处理完毕
# 590 torch.Size([0, 101, 101])
# 处理完毕
# 591 torch.Size([0, 101, 101])
# 处理完毕
# 592 torch.Size([0, 101, 101])
# 处理完毕
# 593 torch.Size([0, 101, 101])
# 处理完毕
# 594 torch.Size([0, 101, 101])
# 处理完毕
# 595 torch.Size([0, 101, 101])
# 处理完毕
# 596 torch.Size([0, 101, 101])
# 处理完毕
# 597 torch.Size([0, 101, 101])
# 处理完毕
# 598 torch.Size([0, 101, 101])
# 处理完毕
# 599 torch.Size([0, 101, 101])
# 处理完毕
# 600 torch.Size([0, 101, 101])
# 处理完毕
# 601 torch.Size([0, 101, 101])
# 处理完毕
# 602 torch.Size([0, 101, 101])
# 处理完毕
# 603 torch.Size([0, 101, 101])
# 处理完毕
# 604 torch.Size([0, 101, 101])
# 处理完毕
# 605 torch.Size([0, 101, 101])
# 处理完毕
# 606 torch.Size([0, 101, 101])
# 处理完毕
# 607 torch.Size([0, 101, 101])
# 处理完毕
# 608 torch.Size([0, 101, 101])
# 处理完毕
# 609 torch.Size([0, 101, 101])
# 处理完毕
# 610 torch.Size([0, 101, 101])
# 处理完毕
# 611 torch.Size([0, 101, 101])
# 处理完毕
# 612 torch.Size([0, 101, 101])
# 处理完毕
# 613 torch.Size([0, 101, 101])
# 处理完毕
# 614 torch.Size([0, 101, 101])
# 处理完毕
# 615 torch.Size([0, 101, 101])
# 处理完毕
# 616 torch.Size([0, 101, 101])
# 处理完毕
# 617 torch.Size([0, 101, 101])
# 处理完毕
# 618 torch.Size([0, 101, 101])
# 处理完毕
# 619 torch.Size([0, 101, 101])
# 处理完毕
# 620 torch.Size([0, 101, 101])
# 处理完毕
# 621 torch.Size([0, 101, 101])
# 处理完毕
# 622 torch.Size([0, 101, 101])
# 处理完毕
# 623 torch.Size([0, 101, 101])
# 处理完毕
# 624 torch.Size([0, 101, 101])
# 处理完毕
# 625 torch.Size([0, 101, 101])
# 处理完毕
# 626 torch.Size([0, 101, 101])
# 处理完毕
# 627 torch.Size([0, 101, 101])
# 处理完毕
# 628 torch.Size([0, 101, 101])
# 处理完毕
# 629 torch.Size([0, 101, 101])
# 处理完毕
# 630 torch.Size([0, 101, 101])
# 处理完毕
# 631 torch.Size([0, 101, 101])
# 处理完毕
# 632 torch.Size([0, 101, 101])
# 处理完毕
# 633 torch.Size([0, 101, 101])
# 处理完毕
# 634 torch.Size([0, 101, 101])
# 处理完毕
# 635 torch.Size([0, 101, 101])
# 处理完毕
# 636 torch.Size([0, 101, 101])
# 处理完毕
# 637 torch.Size([0, 101, 101])
# 处理完毕
# 638 torch.Size([0, 101, 101])
# 处理完毕
# 639 torch.Size([0, 101, 101])
# 处理完毕
# 640 torch.Size([0, 101, 101])
# 处理完毕
# 641 torch.Size([0, 101, 101])
# 处理完毕
# 642 torch.Size([0, 101, 101])
# 处理完毕
# 643 torch.Size([0, 101, 101])
# 处理完毕
# 644 torch.Size([0, 101, 101])
# 处理完毕
# 645 torch.Size([0, 101, 101])
# 处理完毕
# 646 torch.Size([0, 101, 101])
# 处理完毕
# 647 torch.Size([0, 101, 101])
# 处理完毕
# 648 torch.Size([0, 101, 101])
# 处理完毕
# 649 torch.Size([0, 101, 101])
# 处理完毕
# 650 torch.Size([0, 101, 101])
# 处理完毕
# 651 torch.Size([0, 101, 101])
# 处理完毕
# 652 torch.Size([0, 101, 101])
# 处理完毕
# 653 torch.Size([0, 101, 101])
# 处理完毕
# 654 torch.Size([0, 101, 101])
# 处理完毕
# 655 torch.Size([0, 101, 101])
# 处理完毕
# 656 torch.Size([0, 101, 101])
# 处理完毕
# 657 torch.Size([0, 101, 101])
# 处理完毕
# 658 torch.Size([0, 101, 101])
# 处理完毕
# 659 torch.Size([0, 101, 101])
# 处理完毕
# 660 torch.Size([0, 101, 101])
# 处理完毕
# 661 torch.Size([0, 101, 101])
# 处理完毕
# 662 torch.Size([0, 101, 101])
# 处理完毕
# 663 torch.Size([0, 101, 101])
# 处理完毕
# 664 torch.Size([0, 101, 101])
# 处理完毕
# 665 torch.Size([0, 101, 101])
# 处理完毕
# 666 torch.Size([0, 101, 101])
# 处理完毕
# 667 torch.Size([0, 101, 101])
# 处理完毕
# 668 torch.Size([0, 101, 101])
# 处理完毕
# 669 torch.Size([0, 101, 101])
# 处理完毕
# 670 torch.Size([0, 101, 101])
# 处理完毕
# 671 torch.Size([0, 101, 101])
# 处理完毕
# 672 torch.Size([0, 101, 101])
# 处理完毕
# 673 torch.Size([0, 101, 101])
# 处理完毕
# 674 torch.Size([0, 101, 101])
# 2021-11-25_11:56:30

# %%
# print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()).replace(' ','_'))
# dep_batch_file_path = r'/home/chengkun/jupyter_projects/Magic-NLPer-main/data/data_sets/dep_train_batch_pairs'
# f = open(dep_batch_file_path,'rb')
# for step, (inp, targ) in enumerate(train_dataloader, start=1):
    
# #     st = (step-1) * inp.shape[0]
# #     end = st + inp.shape[0]
#     dependency_matrix = pickle.load(f)
#     if step%1 == 0:
#         print(step,inp.shape,targ.shape,dependency_matrix.shape)
# f.close()
# print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()).replace(' ','_'))
